# %% [markdown]
# Compute metrics

# %%
import numpy as np
import sklearn.metrics as skm
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Get predictions (returns array of shape (N, 5))
y_pred_probs = model.predict(x_test)

# 2. Convert probabilities to class IDs (0-4)
y_pred = np.argmax(y_pred_probs, axis=1)

# 3. Get the probability of the chosen class
y_prob = np.max(y_pred_probs, axis=1)

# 4. Handle Labels (Convert from One-Hot to Integers if needed)
# If y_test is (N, 5), convert back to (N,)
y_test_classes = np.argmax(y_test, axis=1) if y_test.ndim > 1 else y_test

# 5. Classification Report
print(skm.classification_report(y_test_classes, y_pred))

# 6. Confusion Matrix
cm = skm.confusion_matrix(y_test_classes, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# 7. Probability analysis (Correct vs Misclassified)
y_prob_correct = y_prob[y_pred == y_test_classes]
y_prob_mis = y_prob[y_pred != y_test_classes]

# %% [markdown]
# Save model to local device.

# %%
# Save the model
model_path = '/kaggle/working/ecg_model.keras'
model.save(model_path)

print(f"Model saved to {model_path}")
